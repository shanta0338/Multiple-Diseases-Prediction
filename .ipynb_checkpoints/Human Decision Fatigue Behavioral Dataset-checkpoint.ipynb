# %% [markdown]
# ## Dataset Link

# %%
# https://www.kaggle.com/datasets/sonalshinde123/human-decision-fatigue-behavioral-dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading a dataset

# %%
df = pd.read_csv(r"C:\Users\Shant\OneDrive\Documents\My Folder\Dataset\human_decision_fatigue_dataset.csv")

# %% [markdown]
# ## Analysis the dataset

# %%
df.head()
# Out:
#    Hours_Awake  Decisions_Made  Task_Switches  Avg_Decision_Time_sec  \
# 0            7              28              7                   2.30
# 1           15              77             22                   3.65
# 2           11              57             23                   3.67
# 3            8              39             10                   2.39
# 4            7              46             16                   3.05
#
#    Sleep_Hours_Last_Night Time_of_Day  Caffeine_Intake_Cups  \
# 0                     5.8     Evening                     0
# 1                     4.5   Afternoon                     3
# 2                     6.8       Night                     2
# 3                     5.3   Afternoon                     1
# 4                     8.2       Night                     1
#
#    Stress_Level_1_10  Error_Rate  Cognitive_Load_Score  \
# 0                2.4       0.000                   2.6
# 1                1.9       0.143                   4.5
# 2                2.1       0.000                   4.1
# 3                1.0       0.000                   2.3
# 4                2.8       0.000                   3.9
#
#    Decision_Fatigue_Score Fatigue_Level System_Recommendation
# 0                    15.6           Low              Continue
# 1                    97.3          High            Take Break
# 2                    55.4      Moderate             Slow Down
# 3                    29.7           Low              Continue
# 4                    19.1           Low              Continue

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Hours_Awake             25000 non-null  int64
#  1   Decisions_Made          25000 non-null  int64
#  2   Task_Switches           25000 non-null  int64
#  3   Avg_Decision_Time_sec   25000 non-null  float64
#  4   Sleep_Hours_Last_Night  25000 non-null  float64
#  5   Time_of_Day             25000 non-null  object
#  6   Caffeine_Intake_Cups    25000 non-null  int64
#  7   Stress_Level_1_10       25000 non-null  float64
#  8   Error_Rate              25000 non-null  float64
#  9   Cognitive_Load_Score    25000 non-null  float64
#  10  Decision_Fatigue_Score  25000 non-null  float64
#  11  Fatigue_Level           25000 non-null  object
#  12  System_Recommendation   25000 non-null  object
# dtypes: float64(6), int64(4), object(3)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#         Hours_Awake  Decisions_Made  Task_Switches  Avg_Decision_Time_sec  \
# count  25000.000000    25000.000000   25000.000000           25000.000000
# mean       9.088280       45.433080      13.623480               2.918346
# std        4.928093       25.611583       8.521595               0.942644
# min        1.000000        0.000000       0.000000               0.500000
# 25%        5.000000       23.000000       7.000000               2.270000
# 50%        9.000000       45.000000      13.000000               2.910000
# 75%       13.000000       67.000000      20.000000               3.550000
# max       17.000000      117.000000      48.000000               6.800000
#
#        Sleep_Hours_Last_Night  Caffeine_Intake_Cups  Stress_Level_1_10  \
# count            25000.000000          25000.000000       25000.000000
# mean                 6.085956              1.897240           2.202736
# std                  1.114586              1.430483           1.329868
# min                  2.000000              0.000000           1.000000
# 25%                  5.300000              1.000000           1.000000
# 50%                  6.100000              2.000000           1.800000
# 75%                  6.900000              3.000000           3.100000
# max                  9.000000              6.000000           8.700000
#
#          Error_Rate  Cognitive_Load_Score  Decision_Fatigue_Score
# count  25000.000000          25000.000000            25000.000000
# mean       0.031877              3.365784               40.579280
# std        0.057457              1.729092               36.704221
# min        0.000000              0.600000                0.000000
# 25%        0.000000              1.900000                0.000000
# 50%        0.000000              3.200000               34.650000
# 75%        0.045000              4.600000               74.200000
# max        0.359000              9.700000              100.000000

# %%
sns.barplot(data = df, x = df.Hours_Awake, y = df.Decisions_Made, ci = None)
# Out:
# C:\Users\Shant\AppData\Local\Temp\ipykernel_22256\2187904999.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data = df, x = df.Hours_Awake, y = df.Decisions_Made, ci = None)
# <Axes: xlabel='Hours_Awake', ylabel='Decisions_Made'>

# %%
sns.histplot(data = df, x = df.Fatigue_Level, y = df.Decision_Fatigue_Score)
# Out:
# <Axes: xlabel='Fatigue_Level', ylabel='Decision_Fatigue_Score'>

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype == object:
        df[col] = label_encoder.fit_transform(df[col])

# %%
x = df.iloc[:, :-1]
y = df.System_Recommendation

# %%
x.shape
# Out:
# (25000, 12)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,shuffle=True, random_state=42)

# %%
scaler = StandardScaler()

# %%
x_train_scaler = scaler.fit_transform(x_train)
x_test_scaler = scaler.fit(x_test)

# %% [markdown]
# ## Building models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
param = {
    'n_neighbors': [5, 11, 13, 21, 31, 51, 101, 121],
    'weights': ['uniform', 'distance'],
    'algorithm': ['ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [10, 30, 50],
    'p': [1, 2],
    'metric': ['cityblock', 'euclidean', 'haversine', 'manhattan', 'nan_euclidean']
}

# %%
knn = KNeighborsClassifier()

# %%
random = RandomizedSearchCV(estimator=knn,param_distributions=param, n_iter=5, pre_dispatch='all', cv=10)

# %%
random.fit(x_train, y_train)
# Out:
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py:927: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_validation.py", line 916, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_scorer.py", line 485, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 450, in score
#     return super().score(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\base.py", line 566, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_classification.py", line 281, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\neighbors\_base.py", line 862, in kneighbors
#     results = ArgKmin.compute(
#               ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py", line 277, in compute
#     return ArgKmin64.compute(
#            ^^^^^^^^^^^^^^^^^^
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 88, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute
#   File "sklearn/metrics/_pairwise_distances_reduction/_datasets_pair.pyx", line 95, in sklearn.metrics._pairwise_distances_reduction._datasets_pair.DatasetsPair64.get_for
#   File "sklearn/metrics/_dist_metrics.pyx", line 2623, in sklearn.metrics._dist_metrics.HaversineDistance64._validate_data
# ValueError: Haversine distance only valid in 2 dimensions
#
#   warnings.warn(
# C:\Users\Shant\OneDrive\Desktop\Data_Science\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [0.99893333 0.99946667        nan 0.99829333 0.99872   ]
#   warnings.warn(
# RandomizedSearchCV(cv=10, estimator=KNeighborsClassifier(), n_iter=5,
#                    param_distributions={'algorithm': ['ball_tree', 'kd_tree',
#                                                       'brute'],
#                                         'leaf_size': [10, 30, 50],
#                                         'metric': ['cityblock', 'euclidean',
#                                                    'haversine', 'manhattan',
#                                                    'nan_euclidean'],
#                                         'n_neighbors': [5, 11, 13, 21, 31, 51,
#                                                         101, 121],
#                                         'p': [1, 2],
#                                         'weights': ['uniform', 'distance']},
#                    pre_dispatch='all')

# %%
y_pred = random.predict(x_test)

# %% [markdown]
# ## Evaluation metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, auc

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2928
#            1       1.00      1.00      1.00      1221
#            2       1.00      1.00      1.00      2101
#
#     accuracy                           1.00      6250
#    macro avg       1.00      1.00      1.00      6250
# weighted avg       1.00      1.00      1.00      6250

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[2928,    0,    0],
#        [   1, 1220,    0],
#        [   0,    0, 2101]])

# %% [markdown]
# ## Saving a model

# %%
import joblib

# %%
best_model = random.best_estimator_
joblib.dump(best_model, 'fatigue_behavioral_best_model.joblib')
# Out:
# ['fatigue_behavioral_best_model.joblib']

# %%
checkpoint = {
    'model': best_model,
    'encoders': le
}
joblib.dump(checkpoint, 'fatigue_behavioral.joblib')
# Out:
# ['fatigue_behavioral.joblib']
