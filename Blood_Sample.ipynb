# %% [markdown]
# # Importing all libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Data cleaning

# %%
df = pd.read_csv(r"D:\Extra\Testing dataset\CSV data\blood_samples_dataset_test.csv")

# %%
df.head(10)
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.001827     0.033693    0.114755   0.997927           0.562604
# 1  0.436679     0.972653    0.084998   0.180909           0.675736
# 2  0.545697     0.324815    0.584467   0.475748           0.558596
# 3  0.172994     0.050351    0.736000   0.782022           0.069435
# 4  0.758534     0.739968    0.597868   0.772683           0.875720
# 5  0.321872     0.554649    0.195652   0.427216           0.807751
# 6  0.677636     0.435037    0.572571   0.965847           0.010580
# 7  0.105103     0.177558    0.169041   0.679138           0.886839
# 8  0.186686     0.210425    0.165662   0.207388           0.918350
# 9  0.448025     0.974133    0.143226   0.471179           0.161697
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.866499    0.578042                 0.914615
# 1         0.563889    0.798382                 0.670361
# 2         0.661007    0.934056                 0.381782
# 3         0.085219    0.032907                 0.460619
# 4         0.860265    0.486189                 0.486686
# 5         0.376964    0.519526                 0.028090
# 6         0.753719    0.262138                 0.789804
# 7         0.714977    0.197501                 0.778653
# 8         0.746808    0.230674                 0.616086
# 9         0.610458    0.470737                 0.275112
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.026864                                   0.038641
# 1                     0.376092                                   0.184890
# 2                     0.500342                                   0.531829
# 3                     0.785448                                   0.491495
# 4                     0.621048                                   0.191756
# 5                     0.382538                                   0.568205
# 6                     0.541149                                   0.550569
# 7                     0.319864                                   0.285914
# 8                     0.533183                                   0.400058
# 9                     0.702463                                   0.423561
#
#    ...     HbA1c  LDL Cholesterol  HDL Cholesterol       ALT       AST  \
# 0  ...  0.653230         0.186104         0.430398  0.016678  0.885352
# 1  ...  0.833540         0.153001         0.458533  0.401845  0.635969
# 2  ...  0.678901         0.220479         0.817151  0.690981  0.101633
# 3  ...  0.381500         0.459396         0.420154  0.798537  0.399236
# 4  ...  0.993381         0.272338         0.663579  0.265227  0.918847
# 5  ...  0.711377         0.887863         0.370344  0.607066  0.936445
# 6  ...  0.196416         0.141203         0.355437  0.468168  0.493548
# 7  ...  0.259719         0.305473         0.867800  0.213141  0.094877
# 8  ...  0.600902         0.812273         0.332766  0.797290  0.190961
# 9  ...  0.435143         0.934164         0.094991  0.795212  0.456302
#
#    Heart Rate  Creatinine  Troponin  C-reactive Protein   Disease
# 0    0.652733    0.788235  0.054788            0.031313  Thalasse
# 1    0.574425    0.047025  0.607985            0.594123  Diabetes
# 2    0.855740    0.551124  0.413294            0.070909  Heart Di
# 3    0.324600    0.499504  0.436662            0.242766  Diabetes
# 4    0.804910    0.571119  0.188368            0.750848  Heart Di
# 5    0.160355    0.108994  0.599071            0.560535  Heart Di
# 6    0.213971    0.059427  0.836447            0.231356  Diabetes
# 7    0.120487    0.211855  0.376829            0.645990  Diabetes
# 8    0.298596    0.877684  0.966106            0.306355  Heart Di
# 9    0.122741    0.820810  0.045505            0.562205  Diabetes
#
# [10 rows x 25 columns]

# %%
df.isnull()
# Out:
#      Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0      False        False       False      False              False
# 1      False        False       False      False              False
# 2      False        False       False      False              False
# 3      False        False       False      False              False
# 4      False        False       False      False              False
# ..       ...          ...         ...        ...                ...
# 481    False        False       False      False              False
# 482    False        False       False      False              False
# 483    False        False       False      False              False
# 484    False        False       False      False              False
# 485    False        False       False      False              False
#
#      Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0              False       False                    False
# 1              False       False                    False
# 2              False       False                    False
# 3              False       False                    False
# 4              False       False                    False
# ..               ...         ...                      ...
# 481            False       False                    False
# 482            False       False                    False
# 483            False       False                    False
# 484            False       False                    False
# 485            False       False                    False
#
#      Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                          False                                      False
# 1                          False                                      False
# 2                          False                                      False
# 3                          False                                      False
# 4                          False                                      False
# ..                           ...                                        ...
# 481                        False                                      False
# 482                        False                                      False
# 483                        False                                      False
# 484                        False                                      False
# 485                        False                                      False
#
#      ...  HbA1c  LDL Cholesterol  HDL Cholesterol    ALT    AST  Heart Rate  \
# 0    ...  False            False            False  False  False       False
# 1    ...  False            False            False  False  False       False
# 2    ...  False            False            False  False  False       False
# 3    ...  False            False            False  False  False       False
# 4    ...  False            False            False  False  False       False
# ..   ...    ...              ...              ...    ...    ...         ...
# 481  ...  False            False            False  False  False       False
# 482  ...  False            False            False  False  False       False
# 483  ...  False            False            False  False  False       False
# 484  ...  False            False            False  False  False       False
# 485  ...  False            False            False  False  False       False
#
#      Creatinine  Troponin  C-reactive Protein  Disease
# 0         False     False               False    False
# 1         False     False               False    False
# 2         False     False               False    False
# 3         False     False               False    False
# 4         False     False               False    False
# ..          ...       ...                 ...      ...
# 481       False     False               False    False
# 482       False     False               False    False
# 483       False     False               False    False
# 484       False     False               False    False
# 485       False     False               False    False
#
# [486 rows x 25 columns]

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Glucose                                    486 non-null    float64
#  1   Cholesterol                                486 non-null    float64
#  2   Hemoglobin                                 486 non-null    float64
#  3   Platelets                                  486 non-null    float64
#  4   White Blood Cells                          486 non-null    float64
#  5   Red Blood Cells                            486 non-null    float64
#  6   Hematocrit                                 486 non-null    float64
#  7   Mean Corpuscular Volume                    486 non-null    float64
#  8   Mean Corpuscular Hemoglobin                486 non-null    float64
#  9   Mean Corpuscular Hemoglobin Concentration  486 non-null    float64
#  10  Insulin                                    486 non-null    float64
#  11  BMI                                        486 non-null    float64
#  12  Systolic Blood Pressure                    486 non-null    float64
#  13  Diastolic Blood Pressure                   486 non-null    float64
#  14  Triglycerides                              486 non-null    float64
#  15  HbA1c                                      486 non-null    float64
#  16  LDL Cholesterol                            486 non-null    float64
#  17  HDL Cholesterol                            486 non-null    float64
#  18  ALT                                        486 non-null    float64
#  19  AST                                        486 non-null    float64
#  20  Heart Rate                                 486 non-null    float64
#  21  Creatinine                                 486 non-null    float64
#  22  Troponin                                   486 non-null    float64
#  23  C-reactive Protein                         486 non-null    float64
#  24  Disease                                    486 non-null    object
# dtypes: float64(24), object(1)
# memory usage: 95.1+ KB

# %%
df.describe()
# Out:
#           Glucose  Cholesterol  Hemoglobin   Platelets  White Blood Cells  \
# count  486.000000   486.000000  486.000000  486.000000         486.000000
# mean     0.490044     0.506797    0.485502    0.528136           0.509783
# std      0.284196     0.282871    0.298818    0.292610           0.290887
# min      0.001827     0.003088    0.000719    0.000006          -0.000206
# 25%      0.236664     0.268021    0.201994    0.276155           0.264944
# 50%      0.496471     0.502397    0.477706    0.538642           0.511102
# 75%      0.727144     0.754638    0.750028    0.789486           0.767896
# max      0.991742     0.999606    0.997876    0.999507           0.999646
#
#        Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# count       486.000000  486.000000               486.000000
# mean          0.504347    0.501042                 0.516185
# std           0.302865    0.294501                 0.279954
# min           0.000552    0.004556                 0.000309
# 25%           0.218573    0.246255                 0.287755
# 50%           0.518103    0.496275                 0.533319
# 75%           0.768466    0.761107                 0.746765
# max           0.997267    1.000857                 0.996362
#
#        Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# count                   486.000000                                 486.000000
# mean                      0.510145                                   0.501105
# std                       0.285213                                   0.290614
# min                      -0.000614                                   0.000719
# 25%                       0.259967                                   0.255839
# 50%                       0.498332                                   0.493929
# 75%                       0.761956                                   0.734817
# max                       0.999234                                   0.999666
#
#        ...  Triglycerides       HbA1c  LDL Cholesterol  HDL Cholesterol  \
# count  ...     486.000000  486.000000       486.000000       486.000000
# mean   ...       0.498538    0.489365         0.501706         0.487933
# std    ...       0.288848    0.290849         0.286729         0.292726
# min    ...       0.001885   -0.000991         0.001036        -0.000546
# 25%    ...       0.238772    0.239302         0.262516         0.229095
# 50%    ...       0.503164    0.481549         0.511373         0.481533
# 75%    ...       0.749527    0.725472         0.756136         0.741867
# max    ...       0.999826    0.999265         0.999567         1.000744
#
#               ALT         AST  Heart Rate  Creatinine    Troponin  \
# count  486.000000  486.000000  486.000000  486.000000  486.000000
# mean     0.500615    0.499675    0.493794    0.515541    0.510077
# std      0.285374    0.301451    0.292400    0.287223    0.294011
# min     -0.000312    0.002047    0.002145    0.008831    0.005714
# 25%      0.251076    0.239369    0.228581    0.262924    0.267101
# 50%      0.515321    0.497846    0.507581    0.526299    0.508479
# 75%      0.739248    0.775458    0.751124    0.777839    0.781128
# max      1.000326    1.000402    0.999857    0.999348    1.000125
#
#        C-reactive Protein
# count          486.000000
# mean             0.517365
# std              0.291645
# min             -0.000991
# 25%              0.263192
# 50%              0.546542
# 75%              0.776940
# max              0.999488
#
# [8 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Glucose', 'Cholesterol', 'Hemoglobin', 'Platelets',
#        'White Blood Cells', 'Red Blood Cells', 'Hematocrit',
#        'Mean Corpuscular Volume', 'Mean Corpuscular Hemoglobin',
#        'Mean Corpuscular Hemoglobin Concentration', 'Insulin', 'BMI',
#        'Systolic Blood Pressure', 'Diastolic Blood Pressure', 'Triglycerides',
#        'HbA1c', 'LDL Cholesterol', 'HDL Cholesterol', 'ALT', 'AST',
#        'Heart Rate', 'Creatinine', 'Troponin', 'C-reactive Protein',
#        'Disease'],
#       dtype='object')

# %%
X = df.iloc[:, 0:-1]
Y = df.iloc[:, -1]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (486, 24)
# (486,)

# %%
Y = LabelEncoder().fit_transform(Y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, train_size=0.8, shuffle=True)

# %% [markdown]
# # Creating model

# %% [markdown]
# # Hyperparameter Optimization with Optuna
# We will use Optuna to optimize the hyperparameters of our stacking pipeline for 20 trials.

# %%
# If Optuna is not installed, uncomment the next line:
# !pip install optuna

import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
    gb_learning_rate = trial.suggest_categorical('gb_learning_rate', [0.1, 0.0001])
    lr_C = trial.suggest_categorical('lr_C', [2.0])
    rf_n_estimators = trial.suggest_categorical('rf_n_estimators', [50, 100, 150, 200])
    rf_criterion = trial.suggest_categorical('rf_criterion', ["log_loss"])
    rf_max_depth = trial.suggest_categorical('rf_max_depth', [20])
    rf_min_samples_leaf = trial.suggest_categorical('rf_min_samples_leaf', [10])
    rf_min_samples_split = trial.suggest_categorical('rf_min_samples_split', [4])
    rf_max_features = trial.suggest_categorical('rf_max_features', ["sqrt", "log2"])

    base_model = [
        ('gb', GradientBoostingClassifier(
            loss='log_loss',
            learning_rate=gb_learning_rate
        )),
        ('lr', LogisticRegression(
            penalty='l2',
            C=lr_C
        ))
    ]
    stack = StackingClassifier(
        estimators=base_model,
        final_estimator=RandomForestClassifier(
            n_estimators=rf_n_estimators,
            criterion=rf_criterion,
            max_depth=rf_max_depth,
            min_samples_leaf=rf_min_samples_leaf,
            min_samples_split=rf_min_samples_split,
            max_features=rf_max_features
        )
    )
    pipe = Pipeline([('scaler', StandardScaler()), ('model', stack)])
    score = cross_val_score(pipe, x_train, y_train, cv=2, n_jobs=-1).mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)

print("Best trial:")
print(study.best_trial)
print("Best parameters:", study.best_params)
# Out:
# [I 2025-06-26 22:39:50,654] A new study created in memory with name: no-name-7e35a97a-3e9e-4a0f-8343-5554c68ed6bc
# [I 2025-06-26 22:39:57,980] Trial 0 finished with value: 0.6108247422680413 and parameters: {'gb_learning_rate': 0.0001, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 0 with value: 0.6108247422680413.
# [I 2025-06-26 22:40:05,162] Trial 1 finished with value: 0.8144329896907216 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 150, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:12,193] Trial 2 finished with value: 0.8092783505154639 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'sqrt'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:19,081] Trial 3 finished with value: 0.6829896907216495 and parameters: {'gb_learning_rate': 0.001, 'lr_C': 2.0, 'rf_n_estimators': 150, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'sqrt'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:26,281] Trial 4 finished with value: 0.6056701030927835 and parameters: {'gb_learning_rate': 0.0001, 'lr_C': 2.0, 'rf_n_estimators': 100, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'sqrt'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:34,423] Trial 5 finished with value: 0.6701030927835052 and parameters: {'gb_learning_rate': 0.001, 'lr_C': 2.0, 'rf_n_estimators': 100, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'sqrt'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:41,140] Trial 6 finished with value: 0.6262886597938144 and parameters: {'gb_learning_rate': 0.0001, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:49,957] Trial 7 finished with value: 0.615979381443299 and parameters: {'gb_learning_rate': 0.0001, 'lr_C': 2.0, 'rf_n_estimators': 100, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'sqrt'}. Best is trial 1 with value: 0.8144329896907216.
# [I 2025-06-26 22:40:58,667] Trial 8 finished with value: 0.8170103092783505 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 8 with value: 0.8170103092783505.
# [I 2025-06-26 22:41:07,281] Trial 9 finished with value: 0.615979381443299 and parameters: {'gb_learning_rate': 0.0001, 'lr_C': 2.0, 'rf_n_estimators': 150, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 8 with value: 0.8170103092783505.
# [I 2025-06-26 22:41:15,345] Trial 10 finished with value: 0.8324742268041236 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:41:23,771] Trial 11 finished with value: 0.8247422680412371 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:41:32,367] Trial 12 finished with value: 0.8221649484536082 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:41:39,948] Trial 13 finished with value: 0.8195876288659794 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:41:47,526] Trial 14 finished with value: 0.8273195876288659 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:41:55,319] Trial 15 finished with value: 0.8170103092783505 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:42:03,513] Trial 16 finished with value: 0.6778350515463918 and parameters: {'gb_learning_rate': 0.001, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:42:10,142] Trial 17 finished with value: 0.8092783505154639 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:42:16,600] Trial 18 finished with value: 0.8144329896907216 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# [I 2025-06-26 22:42:22,803] Trial 19 finished with value: 0.8195876288659794 and parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 200, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}. Best is trial 10 with value: 0.8324742268041236.
# Best trial:
# FrozenTrial(number=10, state=1, values=[0.8324742268041236], datetime_start=datetime.datetime(2025, 6, 26, 22, 41, 7, 282801), datetime_complete=datetime.datetime(2025, 6, 26, 22, 41, 15, 345411), params={'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gb_learning_rate': CategoricalDistribution(choices=(0.1, 0.001, 0.0001)), 'lr_C': CategoricalDistribution(choices=(2.0,)), 'rf_n_estimators': CategoricalDistribution(choices=(50, 100, 150, 200)), 'rf_criterion': CategoricalDistribution(choices=('log_loss',)), 'rf_max_depth': CategoricalDistribution(choices=(20,)), 'rf_min_samples_leaf': CategoricalDistribution(choices=(10,)), 'rf_min_samples_split': CategoricalDistribution(choices=(4,)), 'rf_max_features': CategoricalDistribution(choices=('sqrt', 'log2'))}, trial_id=10, value=None)
# Best parameters: {'gb_learning_rate': 0.1, 'lr_C': 2.0, 'rf_n_estimators': 50, 'rf_criterion': 'log_loss', 'rf_max_depth': 20, 'rf_min_samples_leaf': 10, 'rf_min_samples_split': 4, 'rf_max_features': 'log2'}

# %%
base_model = ([('gb', GradientBoostingClassifier()), ('lr', LogisticRegression())])

# %%
stack = StackingClassifier(estimators= base_model, final_estimator= RandomForestClassifier())

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('model', stack)])

# %%
parameter = {
    'model__gb__loss': ['log_loss'],
    'model__gb__learning_rate': [0.1, 0.001, 0.0001],
    'model__lr__penalty': ['l2'],
    'model__lr__C': [2.0],
    'model__final_estimator__n_estimators': [50, 100, 150, 200],  # Corrected `n_estimators`
    'model__final_estimator__criterion': ["log_loss"],
    'model__final_estimator__max_depth': [20],
    'model__final_estimator__min_samples_leaf': [10],
    'model__final_estimator__min_samples_split': [4],
    'model__final_estimator__max_features': ["sqrt", "log2"],
}

# %%
random_search_cv = RandomizedSearchCV(pipe, param_distributions= parameter, n_iter = 2, cv = 2, n_jobs = -1, verbose=2, error_score='raise')

# %%
random_search_cv.fit(x_train, y_train)
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# c:\Users\Shanta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Shanta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Shanta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# RandomizedSearchCV(cv=2, error_score='raise',
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('model',
#                                               StackingClassifier(estimators=[('gb',
#                                                                               GradientBoostingClassifier()),
#                                                                              ('lr',
#                                                                               LogisticRegression())],
#                                                                  final_estimator=RandomForestClassifier()))]),
#                    n_iter=2, n_jobs=-1,
#                    param_distributions={'model__final_estimator__criterion': ['log_loss'],
#                                         'model__final...: [20],
#                                         'model__final_estimator__max_features': ['sqrt',
#                                                                                  'log2'],
#                                         'model__final_estimator__min_samples_leaf': [10],
#                                         'model__final_estimator__min_samples_split': [4],
#                                         'model__final_estimator__n_estimators': [50,
#                                                                                  100,
#                                                                                  150,
#                                                                                  200],
#                                         'model__gb__learning_rate': [0.1, 0.001,
#                                                                      0.0001],
#                                         'model__gb__loss': ['log_loss'],
#                                         'model__lr__C': [2.0],
#                                         'model__lr__penalty': ['l2']},
#                    verbose=2)

# %%
random_search_cv.score(x_test, y_test)
# Out:
# 0.9387755102040817

# %%
random_search_cv.best_estimator_
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  StackingClassifier(estimators=[('gb',
#                                                  GradientBoostingClassifier()),
#                                                 ('lr',
#                                                  LogisticRegression(C=2.0))],
#                                     final_estimator=RandomForestClassifier(criterion='log_loss',
#                                                                            max_depth=20,
#                                                                            max_features='log2',
#                                                                            min_samples_leaf=10,
#                                                                            min_samples_split=4)))])

# %%
predict = random_search_cv.predict(x_test)

# %%
cm = classification_report(y_test, predict)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        15
#            1       1.00      1.00      1.00        63
#            2       0.00      0.00      0.00         1
#            3       0.50      1.00      0.67         6
#            4       1.00      0.78      0.88         9
#            5       1.00      0.50      0.67         4
#
#     accuracy                           0.94        98
#    macro avg       0.75      0.70      0.70        98
# weighted avg       0.96      0.94      0.94        98
# c:\Users\Shanta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Shanta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Shanta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Save the model

# %%
# import joblib

# # Replace 'model' with your actual trained model variable name
# joblib.dump(random_search_cv, 'blood_model.pkl')
# Out:
# ['blood_model.pkl']
